# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#DRIVE_PATH = "/Users/carolyn/Drive/quantgerry/"
DRIVE_PATH = "/Users/jerrylin/Google Drive/My Drive/CS+/Data/"
def full_path(filename):
    return DRIVE_PATH + filename

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Plot multiple single lines

# %%
graph4 = pd.read_csv(full_path('jul28_simanneal/jerry_test4.2_xy.txt'), sep='\t', 
                     header=None).rename(columns={0:'x', 1:'y'})
graph3 = pd.read_csv(full_path('jul28_simanneal/jerry_test3.2_xy.txt'), sep='\t', 
                     header=None).rename(columns={0:'x', 1:'y'})
graph2 = pd.read_csv(full_path('jul28_simanneal/jerry_test2.3_xy.txt'), sep='\t', 
                     header=None).rename(columns={0:'x', 1:'y'})
graph1 = pd.read_csv(full_path('jul28_simanneal/jerry_test1.2_xy.txt'), sep='\t', 
                     header=None).rename(columns={0:'x', 1:'y'})
graph5 = pd.read_csv(full_path('jul28_simanneal/jerry_test5.2_xy.txt'), sep='\t', 
                     header=None).rename(columns={0:'x', 1:'y'})

stoc1 = pd.read_csv(full_path('jul28_simanneal/stoc_test1.3_xy.txt'), sep='\t', 
                    header=None).rename(columns={0:'x', 1:'y'})

# %%
x1 = list(graph1.loc[:, 'x'])
y1 = list(graph1.loc[:, 'y'])
x2 = list(graph2.loc[:, 'x'])
y2 = list(graph2.loc[:, 'y'])
x3 = list(graph3.loc[:, 'x'])
y3 = list(graph3.loc[:, 'y'])
x4 = list(graph4.loc[:, 'x'])
y4 = list(graph4.loc[:, 'y'])
x5 = list(graph5.loc[:, 'x'])
y5 = list(graph5.loc[:, 'y'])
sx1 = list(stoc1.loc[:, 'x'])
sy1 = list(stoc1.loc[:, 'y'])

# %%
plt.scatter(x1, y1, c='#66f246', marker='.', s=12, label='STARTTEMP 200')
plt.scatter(x2, y2, c='#45ddff', marker='.', s=12, label='STARTTEMP 400')
plt.scatter(x4, y4, c='#f0b9ce', marker='.', s=12, label='STARTTEMP 600')
plt.scatter(x3, y3, c='#ff458f', marker='.', s=12, label='STARTTEMP 800')
plt.legend(loc='upper right')
plt.show()

# %%
#Seed = 0
plt.scatter(x1, y1, c='#f7e794', marker='.', s=12, label='STARTTEMP 200')
plt.scatter(x2, y2, c='#f7cd79', marker='.', s=12, label='STARTTEMP 400')
plt.scatter(x4, y4, c='#f7a540', marker='.', s=12, label='STARTTEMP 600')
plt.scatter(x3, y3, c='#f56811', marker='.', s=12, label='STARTTEMP 800')
plt.scatter(sx1, sy1, c='#0a97fc', marker='.', s=12, label='STOCHASTIC')
plt.legend(loc='upper right')
plt.show()

# %%
#Seed = 0
plt.scatter(x1, y1, c='#ffb14e', marker='.', s=12, label='STARTTEMP 200')
plt.scatter(x2, y2, c='#cd34b5', marker='.', s=12, label='STARTTEMP 400')
plt.scatter(x4, y4, c='#ffd700', marker='.', s=12, label='STARTTEMP 600')
plt.scatter(x3, y3, c='#ea5f94', marker='.', s=12, label='STARTTEMP 800')
plt.scatter(sx1, sy1, c='#0000ff', marker='x', s=20, label='STOCHASTIC')
plt.legend(loc='upper right')
plt.ticklabel_format(style='plain')
plt.savefig('seed0_scatter.png', dpi=300, bbox_inches='tight')

# %%
#Seed = 0
plt.scatter(x1, y1, c='#999933', marker='.', s=12, label='STARTTEMP 200')
plt.scatter(x2, y2, c='#CC6677', marker='.', s=12, label='STARTTEMP 400')
plt.scatter(x4, y4, c='#DDCC77', marker='.', s=12, label='STARTTEMP 600')
plt.scatter(x3, y3, c='#882255', marker='.', s=12, label='STARTTEMP 800')
plt.scatter(sx1, sy1, c='#44AA99', marker='x', s=20, label='STOCHASTIC')
plt.legend(loc='upper right')
plt.ticklabel_format(style='plain')
plt.show()
